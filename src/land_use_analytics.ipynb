# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('..//data//area_used in sq km(cleaned).csv')
df.head()
# Out:
#                      Types of use  Baden-Württemberg (Area in sq km)  \
# 0                    Housing area                            3265.49
# 1       Residential building area                            1519.58
# 2  Industrial and commercial area                             717.21
# 3           Industry and commerce                             508.91
# 4                       Stockpile                              13.94
#
#    Bayern (Area in sq km)  Berlin (Area in sq km)  \
# 0                 5280.19                  491.16
# 1                 2137.67                  217.22
# 2                  893.39                   66.75
# 3                  475.16                   35.67
# 4                    3.35                    0.08
#
#    Brandenburg (Area in sq km)  Bremen (Area in sq km)  \
# 0                      2029.39                  184.99
# 1                       637.48                   71.15
# 2                       448.36                   50.92
# ...

# %% [markdown]
# # State which has consumed most area in total:

# %%
df2 = df.T
df2.head()
# Out:
#                                             0                          1    \
# Types of use                       Housing area  Residential building area
# Baden-Württemberg (Area in sq km)       3265.49                    1519.58
# Bayern (Area in sq km)                  5280.19                    2137.67
# Berlin (Area in sq km)                   491.16                     217.22
# Brandenburg (Area in sq km)             2029.39                     637.48
#
#                                                               2    \
# Types of use                       Industrial and commercial area
# Baden-Württemberg (Area in sq km)                          717.21
# Bayern (Area in sq km)                                     893.39
# Berlin (Area in sq km)                                      66.75
# Brandenburg (Area in sq km)                                448.36
#
#                                                      3          4    \
# ...

# %%
sum_of_area_of_each_state = []

for i in range(len(df2.index)-1):
    if i == 0:
        pass
    else:
        sum_of_area_of_each_state.append(df2.iloc[i].sum())

print('array for sum of area of each state: ',sum_of_area_of_each_state)
print('length of array: ',len(sum_of_area_of_each_state))
# Out:
# array for sum of area of each state:  [505307.7700000003, 992338.5099999995, 13389.629999999992, 418352.18000000017, 6349.239999999998, 11218.519999999999, 297977.0499999998, 329230.68, 672985.3600000001, 486042.47000000026, 280847.83999999985, 36462.299999999996, 260723.39999999985, 290658.45, 222655.63000000012, 229736.29999999987]
# length of array:  16

# %%
sum_for_each_state = {}
# print(df.columns)
j = 0

for i in df.columns:
    if i == "Types of use" or i == "Year":
        pass
    else:
        sum_for_each_state[i] = sum_of_area_of_each_state[j]
        j += 1

print("sum_for_each_state", sum_for_each_state)
# Out:
# sum_for_each_state {'Baden-Württemberg (Area in sq km)': 505307.7700000003, 'Bayern (Area in sq km)': 992338.5099999995, 'Berlin (Area in sq km)': 13389.629999999992, 'Brandenburg (Area in sq km)': 418352.18000000017, 'Bremen (Area in sq km)': 6349.239999999998, 'Hamburg (Area in sq km)': 11218.519999999999, 'Hessen (Area in sq km)': 297977.0499999998, 'Mecklenburg-Vorpommern (Area in sq km)': 329230.68, 'Niedersachsen (Area in sq km)': 672985.3600000001, 'Nordrhein-Westfalen (Area in sq km)': 486042.47000000026, 'Rheinland-Pfalz (Area in sq km)': 280847.83999999985, 'Saarland (Area in sq km)': 36462.299999999996, 'Sachsen (Area in sq km)': 260723.39999999985, 'Sachsen-Anhalt (Area in sq km)': 290658.45, 'Schleswig-Holstein (Area in sq km)': 222655.63000000012, 'Thüringen (Area in sq km)': 229736.29999999987}

# %%
# Create figure and axis objects
plt.figure(figsize=(14, 10))

# Plotting the data
plt.bar(sum_for_each_state.keys(), sum_for_each_state.values(), color='skyblue')

# Adding title and labels
plt.title('Total Area covered for Each State in Germany')
plt.xlabel('State')
plt.ylabel('Total Area (sq km)')

# Rotating x-axis labels for better readability
plt.xticks(rotation=60, ha='right')

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Purpose which has consumed most area in total

# %%
df3 = df.groupby('Types of use').sum()

# %%
sum_of_area_of_each_purpose = []

for i in range(len(df3.index)):
    sum_of_area_of_each_purpose.append(df3.iloc[i].sum())

print('array for sum of area of each purpose: ',sum_of_area_of_each_purpose)
print('length of array: ',len(sum_of_area_of_each_purpose))
# Out:
# array for sum of area of each purpose:  [1283584.48, 16748.89, 26216.63, 39588.22, 43270.08, 16855.28, 759976.46, 18959.690000000002, 247716.17, 57514.630000000005, 40791.35, 42053.64, 14224.4, 16815.29, 44788.08, 19768.03, 24360.5, 61253.18, 14650.06, 35554.24, 22289.64, 111252.05000000002, 80087.26, 16479.95, 50351.020000000004, 16578.35, 15217.57, 140593.41999999998, 43371.490000000005, 2099731.0700000003, 71589.20999999999, 14301.0]
# length of array:  32

# %%
sum_for_each_purpose = {}
# print(df.columns)
j = 0

for i in df3.index:
    sum_for_each_purpose[i] = sum_of_area_of_each_purpose[j]
    j += 1

print("sum_for_each_purpose: ", sum_for_each_purpose)
# Out:
# sum_for_each_purpose:  {'Agriculture': 1283584.48, 'Air transport': 16748.89, 'Area with special functional character': 26216.63, 'Body of running water': 39588.22, 'Body of standing water': 43270.08, 'Cemetery': 16855.28, 'Forest': 759976.46, 'Heath': 18959.690000000002, 'Housing area': 247716.17, 'Industrial and commercial area': 57514.630000000005, 'Industry and commerce': 40791.35, 'Infertile land, area without vegetation': 42053.64, 'Mining company': 14224.4, 'Mire': 16815.29, 'Mixed-use area': 44788.08, 'Moor': 19768.03, 'Open-cast mine, pit, quarry': 24360.5, 'Path': 61253.18, 'Port basin': 14650.06, 'Public park': 35554.24, 'Rail transport': 22289.64, 'Residential building area': 111252.05000000002, 'Road transport': 80087.26, 'Sea': 16479.95, 'Sports, leisure and recreation area': 50351.020000000004, 'Square': 16578.35, 'Stockpile': 15217.57, 'Transport': 140593.41999999998, 'Trees and shrubs': 43371.490000000005, 'Vegetation': 2099731.0700000003, 'Water body': 71589.2099999
# ...

# %%
# Create figure and axis objects
plt.figure(figsize=(14, 10))

# Plotting the data
plt.bar(sum_for_each_purpose.keys(), sum_for_each_purpose.values(), color='orange')

# Adding title and labels
plt.title('Total Area covered for Each purpose in Germany')
plt.xlabel('Purpose')
plt.ylabel('Total Area (sq km)')

# Rotating x-axis labels for better readability
plt.xticks(rotation=60, ha='right')

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # State which has consumed most area in terms of any specific purpose in specific year

# %%
for i in df.columns:
    if i == 'Types of use' or i == 'Year':
        pass
    else:
        # Pivot the DataFrame
        pivot_df = df.pivot_table(index='Types of use', columns='Year', values=i, aggfunc='sum')
        # Plot
        pivot_df.plot(kind='bar', figsize=(30, 6))
        plt.title(f"Bar Plot for {i}", fontdict={'fontsize':25})  # Set the title for the current plot
        plt.show()  # Show the plot
